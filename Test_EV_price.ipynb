# %%
import pickle
import numpy as np
import pandas as pd

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
test_input = pd.DataFrame()

# %%
test_input = pd.DataFrame(
    [[175, 49.0, 280.0, 153, 8.6, 50.0, 500.0, 448.0,
      'JB - Compact', 4323, 1809, 1649, 'SUV']],
    columns=['top_speed_kmh', 'battery_capacity_kWh', 'torque_nm',
       'efficiency_wh_per_km', 'acceleration_0_100_s',
       'fast_charging_power_kw_dc', 'towing_capacity_kg', 'cargo_volume_l',
       'segment', 'length_mm', 'width_mm', 'height_mm', 'car_body_type']
)

pipe.predict(test_input)
# Out:
# array([266.9])

# %%
# !pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ------ --------------------------------- 1.6/9.1 MB 8.0 MB/s eta 0:00:01
#    --------------- ------------------------ 3.4/9.1 MB 7.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.2/9.1 MB 8.1 MB/s eta 0:00:01
#    -------------------------------- ------- 7.3/9.1 MB 8.5 MB/s eta 0:00:01
#    -------------------------------------- - 8.7/9.1 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.1/9.1 MB 8.0 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/795.4 kB ? eta -:--:--
#    ---------------------------------------- 795.4/795.4 kB 5.7 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ---------- ----------------------------- 1.8/6.9 MB 8.2 MB/s eta 0:00:01
#    ------------------- -------------------- 3.4/6.9 MB 8.2 MB/s eta 0:00:01
# ...

# %%
streamlit run app.py
# Out:
#   Cell In[27], line 1
#     streamlit run app.py
#               ^
# SyntaxError: invalid syntax
